# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# License(s): CC-BY-NC-SA-4.0
# Downloading skin-cancer-mnist-ham10000.zip to /content
# 100% 5.18G/5.20G [00:23<00:00, 244MB/s]
# 100% 5.20G/5.20G [00:23<00:00, 233MB/s]

# %%
! mkdir data
! unzip -q skin-cancer-mnist-ham10000.zip -d data
! unzip -q /content/drive/MyDrive/HAM10000_segmentations_lesion_tschandl.zip -d data

# %%
! mkdir models

# %%
pip install -U albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-1.4.17-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (2.9.2)
# Collecting albucore==0.0.17 (from albumentations)
#   Downloading albucore-0.0.17-py3-none-any.whl.metadata (3.1 kB)
# Collecting eval-type-backport (from albumentations)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (4.12.2)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (3.3)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (0.4)
# Downloading albumentations-1.4.17-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 6.6 MB/s eta 0:00:00
# Downloading albucore-0.0.17-py3-none-any.whl (10 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 9.6 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Installing collected packages: opencv-python-headless, eval-type-backport, albucore, albumentations
# Successfully installed albucore-0.0.17 albumentations-1.4.17 eval-type-backport-0.2.0 opencv-python-headless-4.10.0.84

# %%
import albumentations as A
import time
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from tqdm import tqdm
from PIL import Image
from itertools import product
import torch.nn as nn
import copy
from albumentations.pytorch import ToTensorV2
import torch
import torch.nn.functional as Fun
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
# Out:
# Using device: cpu

# %%
DATA_DIR = 'data/'

METADATA_FILE = os.path.join(DATA_DIR, 'HAM10000_metadata.csv')
IMAGE_DIRS = [os.path.join(DATA_DIR, 'HAM10000_images_part_1'),
              os.path.join(DATA_DIR, 'HAM10000_images_part_2')]
MASK_DIR = os.path.join(DATA_DIR, 'HAM10000_segmentations_lesion_tschandl')

metadata = pd.read_csv(METADATA_FILE)

# %%
le = LabelEncoder()
metadata['dx_encoded'] = le.fit_transform(metadata['dx'])
num_classes = len(le.classes_)
print(f"Number of classes: {num_classes}")
print(le.classes_)
print(metadata['image_id'])
# Out:
# Number of classes: 7
# ['akiec' 'bcc' 'bkl' 'df' 'mel' 'nv' 'vasc']
# 0        ISIC_0027419
# 1        ISIC_0025030
# 2        ISIC_0026769
# 3        ISIC_0025661
# 4        ISIC_0031633
#              ...
# 10010    ISIC_0033084
# 10011    ISIC_0033550
# 10012    ISIC_0033536
# 10013    ISIC_0032854
# 10014    ISIC_0032258
# Name: image_id, Length: 10015, dtype: object

# %%
def stratified_extracted_dataset(dataset, target, portion=0.2):
    # Calculate the number of samples to take from each class
    n_samples = int(len(target) * portion)

    # Group indices by class labels
    y_idx = defaultdict(list)
    for i, label in enumerate(target):
        y_idx[label].append(i)

    # Prepare the sampled dataset
    extracted_indices = []

    for label, indices in y_idx.items():
        np.random.shuffle(indices)  # Shuffle the indices for this class
        n_per_class = min(len(indices), n_samples // len(y_idx))  # Samples to take for this class
        extracted_indices.extend(indices[:n_per_class])  # Select the samples

    # Return the new dataset containing only the sampled indices
    return dataset.loc[extracted_indices]

# %%
class SkinCancerDataset(Dataset):
    def __init__(self, dataframe, image_dirs, mask_dir, transform=None):
        """
        Args:
            dataframe (pd.DataFrame): DataFrame containing image information and labels.
            image_dirs (list): List of directories where images are stored.
            mask_dir (str): Directory where segmentation masks are stored.
            transform (callable, optional): Transformations to apply to the images.
            mask_transform (callable, optional): Transformations to apply to the masks.
        """
        self.dataframe = dataframe.reset_index(drop=True)
        self.image_dirs = image_dirs
        self.mask_dir = mask_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def apply_mask(self, image, mask):
        # focus on the lesion area of the image
        return image * np.expand_dims(mask, axis=0)

    def __getitem__(self, idx):
        # Extract image ID and label
        img_id = self.dataframe.loc[idx, 'image_id']
        label = self.dataframe.loc[idx, 'dx_encoded']

        # Find image path
        img_path = None
        for dir in self.image_dirs:
            potential_path = os.path.join(dir, f"{img_id}.jpg")
            if os.path.exists(potential_path):
                img_path = potential_path
                break
        if img_path is None:
            raise FileNotFoundError(f"Image {img_id} not found in specified directories.")

        # Find mask path
        mask_path = os.path.join(self.mask_dir, f"{img_id}_segmentation.png")
        if not os.path.exists(mask_path):
            raise FileNotFoundError(f"Mask for image {img_id} not found in {self.mask_dir}.")

        # Load image
        image = np.array(Image.open(img_path).convert('RGB'))

        # Load mask
        mask = np.array(Image.open(mask_path).convert('L'))  # Grayscale

        # Apply transformations and masking to the image
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']

        masked_image = self.apply_mask(image, mask)

        # Convert label to torch.long
        label = torch.tensor(label, dtype=torch.long)

        return image, label

# %%
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=20, p=0.5),
    A.Resize(224, 224),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

val_test_transform = A.Compose([
    A.Resize(224, 224),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# %%
def train_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels.data)
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct.double() / total

    return epoch_loss, epoch_acc

def eval_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels.data)
            total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = correct.double() / total

    return epoch_loss, epoch_acc

# %%
def alexnet(dr):
  model = torch.hub.load('pytorch/vision:v0.10.0', 'alexnet', pretrained=True)
  model.classifier[0] = nn.Dropout(p=dr)
  model.classifier[3] = nn.Dropout(p=dr)
  model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
  model.eval()
  model = model.to(DEVICE)

  # Define optimizer and scheduler
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
  scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

  return model, criterion, optimizer, scheduler

# %%
def run_epoch(model, optimizer, criterion, scheduler, train_loader, val_loader):
  best_model_wts = copy.deepcopy(model.state_dict())
  best_acc = 0.0
  num_epochs = 20

  for epoch in range(num_epochs):
      print(f'\nEpoch {epoch+1}/{num_epochs}')
      print('-' * 10)

      # Training Phase
      train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, DEVICE)
      print(f'Train Loss: {train_loss:.4f} Acc: {train_acc:.4f}')

      # Validation Phase
      val_loss, val_acc = eval_epoch(model, val_loader, criterion, DEVICE)
      print(f'Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}')

      # Check if this is the best model so far
      if val_acc > best_acc:
          best_acc = val_acc
          best_model_wts = copy.deepcopy(model.state_dict())
          torch.save(model.state_dict(), 'best_alexnet.pth')
          print(f'Best model updated with Val Acc: {best_acc:.4f}')

      # Step the scheduler
      scheduler.step()

  print('\nTraining complete.')
  print(f'Best Validation Accuracy: {best_acc:.4f}')

  return best_acc

# Load the best model weights
# model.load_state_dict(best_model_wts)

# %%
class stratifiedKFold:
  def __init__(self, n_split, shuffle, random_state):
    self.n_split = n_split
    self.shuffle = shuffle
    self.random_state = random_state

  def split(self, X, y):
    if (self.shuffle and self.random_state) is not None:
      np.random.seed(self.random_state)

    idx = np.arange(len(y))
    if self.shuffle:
      np.random.shuffle(idx)

    y_idx = defaultdict(list)
    for i, label in zip(idx, y):
      y_idx[label].append(i)

    splits = [[] for _ in range(self.n_split)]

    for label, i in y_idx.items():
      np.random.shuffle(i)
      split_portions = [len(i) // self.n_split] * self.n_split
      for j in range(len(i) % self.n_split):
        split_portions[j] += 1

      first = 0
      for k in range(self.n_split):
        last = first + split_portions[k]
        splits[k].extend(i[first:last])
        first = last

    for i in range(self.n_split):
      test_idx = splits[i]
      train_idx = np.concatenate([splits[j] for j in range(self.n_split) if j != i])
      yield train_idx, test_idx

    def get_n_splits(self):
        return self.n_split

# %%
def cross_validate(X, y, hyperparameters):
    outer_fold = stratifiedKFold(n_split=5, shuffle=True, random_state=42)
    outer_results = []

    # outer fold
    for train_idx, test_idx in outer_fold.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        inner_fold = stratifiedKFold(n_split=3, shuffle=True, random_state=42)
        best_acc = 0.0
        best_params = None

        # set up hyperparameter combinations
        param_keys = [list(d.keys())[0] for d in hyperparameters]
        param_values = [list(d.values())[0] for d in hyperparameters]
        combinations = product(*param_values)
        hyper_combo = [{param_keys[i]: combo[i] for i in range(len(param_keys))} for combo in combinations]

        for param in hyper_combo:
            dropout_rate = param['dr']
            model, criterion, optimizer, scheduler = alexnet(dropout_rate)
            inner_acc = []

            # inner fold
            for inner_train_idx, inner_val_idx in inner_fold.split(X_train, y_train):
                X_inner_train, X_inner_val = X_train.iloc[inner_train_idx], X_train.iloc[inner_val_idx]

                # TODO: replace/remove based on your own implementation
                # Create Datasets for inner folds
                train_dataset = SkinCancerDataset(X_inner_train, IMAGE_DIRS, MASK_DIR, transform=train_transform)
                val_dataset = SkinCancerDataset(X_inner_val, IMAGE_DIRS, MASK_DIR, transform=val_test_transform)

                # Create DataLoaders for inner folds
                BATCH_SIZE = 128
                train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
                val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

                best_inner_acc = run_epoch(model, optimizer, criterion, scheduler, train_loader, val_loader)
                inner_acc.append(best_inner_acc)

            mean_inner_acc = np.mean(inner_acc)

            # Update best score and parameters
            if mean_inner_acc > best_acc:
                best_acc = mean_inner_acc
                best_params = param
                print(best_params)

        # Retrain the model with the best parameters on the entire outer training set
        dropout_rate = best_params['dr']
        model, criterion, optimizer, scheduler = alexnet(dropout_rate)

        # Create Datasets for outer folds
        train_dataset = SkinCancerDataset(X_train, IMAGE_DIRS, MASK_DIR, transform=train_transform)
        test_dataset = SkinCancerDataset(X_test, IMAGE_DIRS, MASK_DIR, transform=val_test_transform)

        # Create DataLoaders for outer folds
        BATCH_SIZE = 128
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
        test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

        best_test_acc = 0.0

        best_outer_acc = run_epoch(model, optimizer, criterion, scheduler, train_loader, test_loader)

        if best_outer_acc > best_test_acc:
            best_test_acc = best_outer_acc

        outer_results.append((best_params, best_test_acc))

    hyper_result = []
    for params, acc in outer_results:
        hyper_result.append({'dr': params['dr'], 'accuracy': acc.item()})

    hyper_df = pd.DataFrame(hyper_result)
    file_path = 'drive/MyDrive/hyper_result.csv'
    hyper_df.to_csv(file_path, index=False)

    return outer_results

# %%
extracted = stratified_extracted_dataset(metadata, metadata['dx_encoded'], portion = 0.2)

# %%
hyperparameters = [
    {'dr': [0.5, 0.6, 0.7]}
]

hyper_tuning_result = cross_validate(extracted, extracted['dx_encoded'], hyperparameters)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20
# ----------
# Train Loss: 1.7829 Acc: 0.3188
# Val Loss: 1.4694 Acc: 0.4346
# Best model updated with Val Acc: 0.4346
#
# Epoch 2/20
# ----------
# Train Loss: 1.3105 Acc: 0.5056
# Val Loss: 1.2846 Acc: 0.5233
# Best model updated with Val Acc: 0.5233
#
# Epoch 3/20
# ----------
# Train Loss: 1.0392 Acc: 0.5984
# Val Loss: 1.1117 Acc: 0.5809
# Best model updated with Val Acc: 0.5809
#
# Epoch 4/20
# ----------
# Train Loss: 0.8676 Acc: 0.6801
# Val Loss: 1.1103 Acc: 0.5565
#
# Epoch 5/20
# ----------
# Train Loss: 0.7279 Acc: 0.7394
# Val Loss: 1.0310 Acc: 0.6053
# Best model updated with Val Acc: 0.6053
#
# Epoch 6/20
# ----------
# Train Loss: 0.6207 Acc: 0.7673
# Val Loss: 1.0070 Acc: 0.6297
# Best model updated with Val Acc: 0.6297
#
# Epoch 7/20
# ----------
# Train Loss: 0.5130 Acc: 0.8110
# Val Loss: 1.0407 Acc: 0.6364
# Best model updated with Val Acc: 0.6364
#
# Epoch 8/20
# ----------
# Train Loss: 0.4589 Acc: 0.8311
# Val Loss: 1.0169 Acc: 0.6364
#
# Epoch 9/20
# ----------
# Train Loss: 0.4129 Acc: 0.8591
# Val Loss: 1.0366 Acc: 0.6386
# Best model updated with Val Acc: 0.6386
#
# Epoch 10/20
# ----------
# Train Loss: 0.3819 Acc: 0.8691
# Val Loss: 1.0152 Acc: 0.6430
# Best model updated with Val Acc: 0.6430
#
# Epoch 11/20
# ----------
# Train Loss: 0.3900 Acc: 0.8702
# Val Loss: 1.0089 Acc: 0.6452
# Best model updated with Val Acc: 0.6452
#
# Epoch 12/20
# ----------
# Train Loss: 0.3587 Acc: 0.8837
# Val Loss: 1.0234 Acc: 0.6541
# Best model updated with Val Acc: 0.6541
#
# Epoch 13/20
# ----------
# Train Loss: 0.3795 Acc: 0.8725
# Val Loss: 1.0183 Acc: 0.6541
#
# Epoch 14/20
# ----------
# Train Loss: 0.3639 Acc: 0.8758
# Val Loss: 1.0213 Acc: 0.6452
#
# Epoch 15/20
# ----------
# Train Loss: 0.3617 Acc: 0.8770
# Val Loss: 1.0207 Acc: 0.6475
#
# Epoch 16/20
# ----------
# Train Loss: 0.3467 Acc: 0.8837
# Val Loss: 1.0205 Acc: 0.6452
#
# Epoch 17/20
# ----------
# Train Loss: 0.3495 Acc: 0.8837
# Val Loss: 1.0212 Acc: 0.6497
#
# Epoch 18/20
# ----------
# Train Loss: 0.3570 Acc: 0.8915
# Val Loss: 1.0206 Acc: 0.6519
#
# Epoch 19/20
# ----------
# Train Loss: 0.3571 Acc: 0.8859
# Val Loss: 1.0200 Acc: 0.6563
# Best model updated with Val Acc: 0.6563
#
# Epoch 20/20
# ----------
# Train Loss: 0.3712 Acc: 0.8736
# Val Loss: 1.0201 Acc: 0.6541
#
# Training complete.
# Best Validation Accuracy: 0.6563
#
# Epoch 1/20
# ----------
# Train Loss: 0.6998 Acc: 0.7650
# Val Loss: 0.2472 Acc: 0.9262
# Best model updated with Val Acc: 0.9262
#
# Epoch 2/20
# ----------
# Train Loss: 0.7045 Acc: 0.7584
# Val Loss: 0.2474 Acc: 0.9262
#
# Epoch 3/20
# ----------
# Train Loss: 0.7200 Acc: 0.7550
# Val Loss: 0.2475 Acc: 0.9262
#
# Epoch 4/20
# ----------
# Train Loss: 0.6964 Acc: 0.7628
# Val Loss: 0.2477 Acc: 0.9262
#
# Epoch 5/20
# ----------
# Train Loss: 0.7189 Acc: 0.7684
# Val Loss: 0.2478 Acc: 0.9262
#
# Epoch 6/20
# ----------
# Train Loss: 0.6840 Acc: 0.7584
# Val Loss: 0.2480 Acc: 0.9262
#
# Epoch 7/20
# ----------
# Train Loss: 0.6977 Acc: 0.7561
# Val Loss: 0.2481 Acc: 0.9262
#
# Epoch 8/20
# ----------
# Train Loss: 0.6867 Acc: 0.7628
# Val Loss: 0.2482 Acc: 0.9262
#
# Epoch 9/20
# ----------
# Train Loss: 0.6784 Acc: 0.7784
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 10/20
# ----------
# Train Loss: 0.6801 Acc: 0.7717
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 11/20
# ----------
# Train Loss: 0.7166 Acc: 0.7639
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 12/20
# ----------
# Train Loss: 0.7015 Acc: 0.7739
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 13/20
# ----------
# Train Loss: 0.6978 Acc: 0.7650
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 14/20
# ----------
# Train Loss: 0.7126 Acc: 0.7428
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 15/20
# ----------
# Train Loss: 0.6825 Acc: 0.7650
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 16/20
# ----------
# Train Loss: 0.6994 Acc: 0.7762
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 17/20
# ----------
# Train Loss: 0.6915 Acc: 0.7539
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 18/20
# ----------
# Train Loss: 0.6807 Acc: 0.7739
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 19/20
# ----------
# Train Loss: 0.6876 Acc: 0.7628
# Val Loss: 0.2483 Acc: 0.9262
#
# Epoch 20/20
# ----------
# Train Loss: 0.6958 Acc: 0.7661
# Val Loss: 0.2483 Acc: 0.9262
#
# Training complete.
# Best Validation Accuracy: 0.9262
#
# Epoch 1/20
# ----------
# Train Loss: 0.6997 Acc: 0.7661
# Val Loss: 0.2555 Acc: 0.9306
# Best model updated with Val Acc: 0.9306
#
# Epoch 2/20
# ----------
# Train Loss: 0.6982 Acc: 0.7695
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 3/20
# ----------
# Train Loss: 0.7202 Acc: 0.7483
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 4/20
# ----------
# Train Loss: 0.6894 Acc: 0.7628
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 5/20
# ----------
# Train Loss: 0.7099 Acc: 0.7684
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 6/20
# ----------
# Train Loss: 0.7344 Acc: 0.7428
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 7/20
# ----------
# Train Loss: 0.6925 Acc: 0.7684
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 8/20
# ----------
# Train Loss: 0.6909 Acc: 0.7684
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 9/20
# ----------
# Train Loss: 0.7051 Acc: 0.7695
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 10/20
# ----------
# Train Loss: 0.7037 Acc: 0.7628
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 11/20
# ----------
# Train Loss: 0.6869 Acc: 0.7572
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 12/20
# ----------
# Train Loss: 0.6886 Acc: 0.7572
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 13/20
# ----------
# Train Loss: 0.7034 Acc: 0.7539
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 14/20
# ----------
# Train Loss: 0.6931 Acc: 0.7673
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 15/20
# ----------
# Train Loss: 0.7161 Acc: 0.7606
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 16/20
# ----------
# Train Loss: 0.7189 Acc: 0.7584
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 17/20
# ----------
# Train Loss: 0.7242 Acc: 0.7450
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 18/20
# ----------
# Train Loss: 0.6976 Acc: 0.7661
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 19/20
# ----------
# Train Loss: 0.7150 Acc: 0.7483
# Val Loss: 0.2555 Acc: 0.9306
#
# Epoch 20/20
# ----------
# Train Loss: 0.6973 Acc: 0.7639
# Val Loss: 0.2555 Acc: 0.9306
#
# Training complete.
# Best Validation Accuracy: 0.9306
# {'dr': 0.5}
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.6571 Acc: 0.3602
# Val Loss: 1.3715 Acc: 0.4656
# Best model updated with Val Acc: 0.4656
#
# Epoch 2/20
# ----------
# Train Loss: 1.2138 Acc: 0.5716
# Val Loss: 1.1943 Acc: 0.5765
# Best model updated with Val Acc: 0.5765
#
# Epoch 3/20
# ----------
# Train Loss: 0.9661 Acc: 0.6454
# Val Loss: 1.1164 Acc: 0.5765
#
# Epoch 4/20
# ----------
# Train Loss: 0.7986 Acc: 0.7002
# Val Loss: 0.9908 Acc: 0.6319
# Best model updated with Val Acc: 0.6319
#
# Epoch 5/20
# ----------
# Train Loss: 0.7261 Acc: 0.7383
# Val Loss: 1.0480 Acc: 0.6120
#
# Epoch 6/20
# ----------
# Train Loss: 0.6622 Acc: 0.7528
# Val Loss: 1.0198 Acc: 0.6408
# Best model updated with Val Acc: 0.6408
#
# Epoch 7/20
# ----------
# Train Loss: 0.5794 Acc: 0.8031
# Val Loss: 0.9754 Acc: 0.6763
# Best model updated with Val Acc: 0.6763
#
# Epoch 8/20
# ----------
# Train Loss: 0.4944 Acc: 0.8143
# Val Loss: 0.9422 Acc: 0.6851
# Best model updated with Val Acc: 0.6851
#
# Epoch 9/20
# ----------
# Train Loss: 0.4411 Acc: 0.8423
# Val Loss: 0.9287 Acc: 0.6918
# Best model updated with Val Acc: 0.6918
#
# Epoch 10/20
# ----------
# Train Loss: 0.4403 Acc: 0.8412
# Val Loss: 0.9257 Acc: 0.6962
# Best model updated with Val Acc: 0.6962
#
# Epoch 11/20
# ----------
# Train Loss: 0.4337 Acc: 0.8434
# Val Loss: 0.9415 Acc: 0.6962
#
# Epoch 12/20
# ----------
# Train Loss: 0.4242 Acc: 0.8512
# Val Loss: 0.9373 Acc: 0.6896
#
# Epoch 13/20
# ----------
# Train Loss: 0.4072 Acc: 0.8501
# Val Loss: 0.9383 Acc: 0.6918
#
# Epoch 14/20
# ----------
# Train Loss: 0.4238 Acc: 0.8400
# Val Loss: 0.9461 Acc: 0.6874
#
# Epoch 15/20
# ----------
# Train Loss: 0.3998 Acc: 0.8579
# Val Loss: 0.9454 Acc: 0.6874
#
# Epoch 16/20
# ----------
# Train Loss: 0.3812 Acc: 0.8702
# Val Loss: 0.9448 Acc: 0.6874
#
# Epoch 17/20
# ----------
# Train Loss: 0.4074 Acc: 0.8613
# Val Loss: 0.9437 Acc: 0.6874
#
# Epoch 18/20
# ----------
# Train Loss: 0.3969 Acc: 0.8535
# Val Loss: 0.9441 Acc: 0.6874
#
# Epoch 19/20
# ----------
# Train Loss: 0.4026 Acc: 0.8468
# Val Loss: 0.9450 Acc: 0.6874
#
# Epoch 20/20
# ----------
# Train Loss: 0.3997 Acc: 0.8579
# Val Loss: 0.9446 Acc: 0.6874
#
# Training complete.
# Best Validation Accuracy: 0.6962
#
# Epoch 1/20
# ----------
# Train Loss: 0.7147 Acc: 0.7628
# Val Loss: 0.2931 Acc: 0.8949
# Best model updated with Val Acc: 0.8949
#
# Epoch 2/20
# ----------
# Train Loss: 0.6791 Acc: 0.7684
# Val Loss: 0.2932 Acc: 0.8949
#
# Epoch 3/20
# ----------
# Train Loss: 0.7013 Acc: 0.7561
# Val Loss: 0.2933 Acc: 0.8949
#
# Epoch 4/20
# ----------
# Train Loss: 0.6980 Acc: 0.7561
# Val Loss: 0.2935 Acc: 0.8949
#
# Epoch 5/20
# ----------
# Train Loss: 0.6851 Acc: 0.7784
# Val Loss: 0.2936 Acc: 0.8949
#
# Epoch 6/20
# ----------
# Train Loss: 0.6974 Acc: 0.7572
# Val Loss: 0.2937 Acc: 0.8949
#
# Epoch 7/20
# ----------
# Train Loss: 0.7038 Acc: 0.7717
# Val Loss: 0.2939 Acc: 0.8949
#
# Epoch 8/20
# ----------
# Train Loss: 0.6975 Acc: 0.7673
# Val Loss: 0.2941 Acc: 0.8949
#
# Epoch 9/20
# ----------
# Train Loss: 0.7029 Acc: 0.7795
# Val Loss: 0.2941 Acc: 0.8949
#
# Epoch 10/20
# ----------
# Train Loss: 0.7040 Acc: 0.7650
# Val Loss: 0.2941 Acc: 0.8949
#
# Epoch 11/20
# ----------
# Train Loss: 0.6877 Acc: 0.7784
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 12/20
# ----------
# Train Loss: 0.6730 Acc: 0.7661
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 13/20
# ----------
# Train Loss: 0.7122 Acc: 0.7595
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 14/20
# ----------
# Train Loss: 0.7054 Acc: 0.7628
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 15/20
# ----------
# Train Loss: 0.7184 Acc: 0.7528
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 16/20
# ----------
# Train Loss: 0.7004 Acc: 0.7661
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 17/20
# ----------
# Train Loss: 0.6904 Acc: 0.7751
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 18/20
# ----------
# Train Loss: 0.6871 Acc: 0.7673
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 19/20
# ----------
# Train Loss: 0.7042 Acc: 0.7650
# Val Loss: 0.2942 Acc: 0.8949
#
# Epoch 20/20
# ----------
# Train Loss: 0.6757 Acc: 0.7539
# Val Loss: 0.2942 Acc: 0.8949
#
# Training complete.
# Best Validation Accuracy: 0.8949
#
# Epoch 1/20
# ----------
# Train Loss: 0.7018 Acc: 0.7595
# Val Loss: 0.2682 Acc: 0.9239
# Best model updated with Val Acc: 0.9239
#
# Epoch 2/20
# ----------
# Train Loss: 0.7450 Acc: 0.7450
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 3/20
# ----------
# Train Loss: 0.7105 Acc: 0.7494
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 4/20
# ----------
# Train Loss: 0.7272 Acc: 0.7595
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 5/20
# ----------
# Train Loss: 0.7067 Acc: 0.7517
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 6/20
# ----------
# Train Loss: 0.7184 Acc: 0.7584
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 7/20
# ----------
# Train Loss: 0.7081 Acc: 0.7483
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 8/20
# ----------
# Train Loss: 0.7208 Acc: 0.7450
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 9/20
# ----------
# Train Loss: 0.7230 Acc: 0.7461
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 10/20
# ----------
# Train Loss: 0.7239 Acc: 0.7394
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 11/20
# ----------
# Train Loss: 0.7423 Acc: 0.7550
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 12/20
# ----------
# Train Loss: 0.7044 Acc: 0.7528
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 13/20
# ----------
# Train Loss: 0.7332 Acc: 0.7561
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 14/20
# ----------
# Train Loss: 0.7090 Acc: 0.7606
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 15/20
# ----------
# Train Loss: 0.7758 Acc: 0.7439
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 16/20
# ----------
# Train Loss: 0.7141 Acc: 0.7572
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 17/20
# ----------
# Train Loss: 0.7114 Acc: 0.7539
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 18/20
# ----------
# Train Loss: 0.7364 Acc: 0.7305
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 19/20
# ----------
# Train Loss: 0.7130 Acc: 0.7494
# Val Loss: 0.2682 Acc: 0.9239
#
# Epoch 20/20
# ----------
# Train Loss: 0.7198 Acc: 0.7539
# Val Loss: 0.2682 Acc: 0.9239
#
# Training complete.
# Best Validation Accuracy: 0.9239
# {'dr': 0.6}
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.7878 Acc: 0.3009
# Val Loss: 1.4597 Acc: 0.4457
# Best model updated with Val Acc: 0.4457
#
# Epoch 2/20
# ----------
# Train Loss: 1.3644 Acc: 0.4922
# Val Loss: 1.3197 Acc: 0.5188
# Best model updated with Val Acc: 0.5188
#
# Epoch 3/20
# ----------
# Train Loss: 1.1216 Acc: 0.5872
# Val Loss: 1.1414 Acc: 0.5432
# Best model updated with Val Acc: 0.5432
#
# Epoch 4/20
# ----------
# Train Loss: 0.9290 Acc: 0.6588
# Val Loss: 1.0648 Acc: 0.5721
# Best model updated with Val Acc: 0.5721
#
# Epoch 5/20
# ----------
# Train Loss: 0.8253 Acc: 0.6913
# Val Loss: 0.9833 Acc: 0.6053
# Best model updated with Val Acc: 0.6053
#
# Epoch 6/20
# ----------
# Train Loss: 0.7122 Acc: 0.7416
# Val Loss: 0.9816 Acc: 0.6275
# Best model updated with Val Acc: 0.6275
#
# Epoch 7/20
# ----------
# Train Loss: 0.6383 Acc: 0.7573
# Val Loss: 0.9818 Acc: 0.6386
# Best model updated with Val Acc: 0.6386
#
# Epoch 8/20
# ----------
# Train Loss: 0.5705 Acc: 0.7707
# Val Loss: 0.9715 Acc: 0.6319
#
# Epoch 9/20
# ----------
# Train Loss: 0.5405 Acc: 0.8199
# Val Loss: 0.9628 Acc: 0.6231
#
# Epoch 10/20
# Val Loss: 0.3682 Acc: 0.8702
#
# Epoch 19/20
# ----------
# Train Loss: 0.7522 Acc: 0.7283
# Val Loss: 0.3682 Acc: 0.8702
#
# Epoch 20/20
# ----------
# Train Loss: 0.7750 Acc: 0.7494
# Val Loss: 0.3682 Acc: 0.8702
#
# Training complete.
# Best Validation Accuracy: 0.8725
#
# Epoch 1/20
# ----------
# Train Loss: 0.7780 Acc: 0.7238
# Val Loss: 0.3381 Acc: 0.8949
# Best model updated with Val Acc: 0.8949
#
# Epoch 2/20
# ----------
# Train Loss: 0.7424 Acc: 0.7149
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 3/20
# ----------
# Train Loss: 0.8065 Acc: 0.6960
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 4/20
# ----------
# Train Loss: 0.8274 Acc: 0.7082
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 5/20
# ----------
# Train Loss: 0.8026 Acc: 0.7071
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 6/20
# ----------
# Train Loss: 0.7837 Acc: 0.7227
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 7/20
# ----------
# Train Loss: 0.8367 Acc: 0.7171
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 8/20
# ----------
# Train Loss: 0.7822 Acc: 0.7116
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 9/20
# ----------
# Train Loss: 0.7687 Acc: 0.7350
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 10/20
# ----------
# Train Loss: 0.8111 Acc: 0.7105
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 11/20
# ----------
# Train Loss: 0.7929 Acc: 0.7339
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 12/20
# ----------
# Train Loss: 0.7799 Acc: 0.7127
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 13/20
# ----------
# Train Loss: 0.7731 Acc: 0.7205
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 14/20
# ----------
# Train Loss: 0.7879 Acc: 0.7249
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 15/20
# ----------
# Train Loss: 0.7726 Acc: 0.7272
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 16/20
# ----------
# Train Loss: 0.7807 Acc: 0.7283
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 17/20
# ----------
# Train Loss: 0.7680 Acc: 0.7227
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 18/20
# ----------
# Train Loss: 0.7773 Acc: 0.7149
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 19/20
# ----------
# Train Loss: 0.7834 Acc: 0.7105
# Val Loss: 0.3381 Acc: 0.8949
#
# Epoch 20/20
# ----------
# Train Loss: 0.7680 Acc: 0.7183
# Val Loss: 0.3381 Acc: 0.8949
#
# Training complete.
# Best Validation Accuracy: 0.8949
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.6365 Acc: 0.3621
# Val Loss: 1.2243 Acc: 0.5380
# Best model updated with Val Acc: 0.5380
#
# Epoch 2/20
# ----------
# Train Loss: 1.1674 Acc: 0.5673
# Val Loss: 1.0357 Acc: 0.6170
# Best model updated with Val Acc: 0.6170
#
# Epoch 3/20
# ----------
# Train Loss: 0.9377 Acc: 0.6401
# Val Loss: 1.0577 Acc: 0.6053
#
# Epoch 4/20
# ----------
# Train Loss: 0.8256 Acc: 0.6900
# Val Loss: 0.9331 Acc: 0.6433
# Best model updated with Val Acc: 0.6433
#
# Epoch 5/20
# ----------
# Train Loss: 0.6842 Acc: 0.7413
# Val Loss: 0.9337 Acc: 0.6637
# Best model updated with Val Acc: 0.6637
#
# Epoch 6/20
# ----------
# Train Loss: 0.6047 Acc: 0.7770
# Val Loss: 0.9087 Acc: 0.6754
# Best model updated with Val Acc: 0.6754
#
# Epoch 7/20
# ----------
# Train Loss: 0.5258 Acc: 0.7993
# Val Loss: 0.9034 Acc: 0.6725
#
# Epoch 8/20
# ----------
# Train Loss: 0.4188 Acc: 0.8550
# Val Loss: 0.8766 Acc: 0.6930
# Best model updated with Val Acc: 0.6930
#
# Epoch 9/20
# ----------
# Train Loss: 0.3863 Acc: 0.8543
# Val Loss: 0.8682 Acc: 0.6930
#
# Epoch 10/20
# ----------
# Train Loss: 0.3798 Acc: 0.8632
# Val Loss: 0.8695 Acc: 0.6959
# Best model updated with Val Acc: 0.6959
#
# Epoch 11/20
# ----------
# Train Loss: 0.3831 Acc: 0.8617
# Val Loss: 0.8907 Acc: 0.7105
# Best model updated with Val Acc: 0.7105
#
# Epoch 12/20
# ----------
# Train Loss: 0.3720 Acc: 0.8625
# Val Loss: 0.8707 Acc: 0.7047
#
# Epoch 13/20
# ----------
# Train Loss: 0.3577 Acc: 0.8677
# Val Loss: 0.8818 Acc: 0.7047
#
# Epoch 14/20
# ----------
# Train Loss: 0.3639 Acc: 0.8781
# Val Loss: 0.8856 Acc: 0.7135
# Best model updated with Val Acc: 0.7135
#
# Epoch 15/20
# ----------
# Train Loss: 0.3268 Acc: 0.8810
# Val Loss: 0.8847 Acc: 0.7135
#
# Epoch 16/20
# ----------
# Train Loss: 0.3298 Acc: 0.8892
# Val Loss: 0.8826 Acc: 0.7135
#
# Epoch 17/20
# ----------
# Train Loss: 0.3274 Acc: 0.8825
# Val Loss: 0.8825 Acc: 0.7135
#
# Epoch 18/20
# ----------
# Train Loss: 0.3298 Acc: 0.8840
# Val Loss: 0.8844 Acc: 0.7135
#
# Epoch 19/20
# ----------
# Train Loss: 0.3288 Acc: 0.8914
# Val Loss: 0.8871 Acc: 0.7105
#
# Epoch 20/20
# ----------
# Train Loss: 0.3322 Acc: 0.8885
# Val Loss: 0.8910 Acc: 0.7105
#
# Training complete.
# Best Validation Accuracy: 0.7135
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.7147 Acc: 0.3289
# Val Loss: 1.3626 Acc: 0.4967
# Best model updated with Val Acc: 0.4967
#
# Epoch 2/20
# ----------
# Train Loss: 1.2791 Acc: 0.5240
# Val Loss: 1.2530 Acc: 0.5188
# Best model updated with Val Acc: 0.5188
#
# Epoch 3/20
# ----------
# Train Loss: 1.1529 Acc: 0.5764
# Val Loss: 1.1456 Acc: 0.5828
# Best model updated with Val Acc: 0.5828
#
# Epoch 4/20
# ----------
# Train Loss: 1.0546 Acc: 0.5931
# Val Loss: 1.3495 Acc: 0.5188
#
# Epoch 5/20
# ----------
# Train Loss: 0.9829 Acc: 0.6265
# Val Loss: 1.0510 Acc: 0.6093
# Best model updated with Val Acc: 0.6093
#
# Epoch 6/20
# ----------
# Train Loss: 0.8457 Acc: 0.6990
# Val Loss: 1.0978 Acc: 0.5960
#
# Epoch 7/20
# ----------
# Train Loss: 0.8010 Acc: 0.7012
# Val Loss: 1.1147 Acc: 0.5762
#
# Epoch 8/20
# ----------
# Train Loss: 0.7518 Acc: 0.7023
# Val Loss: 1.0542 Acc: 0.5960
#
# Epoch 9/20
# ----------
# Train Loss: 0.6574 Acc: 0.7592
# Val Loss: 1.0197 Acc: 0.6203
# Best model updated with Val Acc: 0.6203
#
# Epoch 10/20
# ----------
# Train Loss: 0.6122 Acc: 0.7860
# Val Loss: 1.0290 Acc: 0.6203
#
# Epoch 11/20
# ----------
# Train Loss: 0.5953 Acc: 0.7860
# Val Loss: 1.0289 Acc: 0.6071
#
# Epoch 12/20
# ----------
# Train Loss: 0.6053 Acc: 0.7770
# Val Loss: 1.0268 Acc: 0.6093
#
# Epoch 13/20
# ----------
# Train Loss: 0.5719 Acc: 0.8116
# Val Loss: 1.0429 Acc: 0.6225
# Best model updated with Val Acc: 0.6225
#
# Epoch 14/20
# ----------
# Train Loss: 0.5622 Acc: 0.7960
# Val Loss: 1.0305 Acc: 0.6225
#
# Epoch 15/20
# ----------
# Train Loss: 0.5646 Acc: 0.7971
# Val Loss: 1.0277 Acc: 0.6269
# Best model updated with Val Acc: 0.6269
#
# Epoch 16/20
# ----------
# Train Loss: 0.5449 Acc: 0.8127
# Val Loss: 1.0273 Acc: 0.6225
#
# Epoch 17/20
# ----------
# Train Loss: 0.5623 Acc: 0.7949
# Val Loss: 1.0270 Acc: 0.6225
#
# Epoch 18/20
# ----------
# Train Loss: 0.5574 Acc: 0.7993
# Val Loss: 1.0284 Acc: 0.6269
#
# Epoch 19/20
# ----------
# Train Loss: 0.5476 Acc: 0.8116
# Val Loss: 1.0308 Acc: 0.6247
#
# Epoch 20/20
# ----------
# Train Loss: 0.5350 Acc: 0.8027
# Val Loss: 1.0312 Acc: 0.6269
#
# Training complete.
# Best Validation Accuracy: 0.6269
#
# Epoch 1/20
# ----------
# Train Loss: 0.8282 Acc: 0.7078
# Val Loss: 0.4595 Acc: 0.8467
# Best model updated with Val Acc: 0.8467
#
# Epoch 2/20
# ----------
# Train Loss: 0.7943 Acc: 0.7178
# Val Loss: 0.4594 Acc: 0.8467
#
# Epoch 3/20
# ----------
# Train Loss: 0.8375 Acc: 0.7056
# Val Loss: 0.4593 Acc: 0.8467
#
# Epoch 4/20
# ----------
# Train Loss: 0.8428 Acc: 0.7078
# Val Loss: 0.4592 Acc: 0.8467
#
# Epoch 5/20
# ----------
# Train Loss: 0.8160 Acc: 0.7100
# Val Loss: 0.4591 Acc: 0.8467
#
# Epoch 6/20
# ----------
# Train Loss: 0.8358 Acc: 0.7056
# Val Loss: 0.4591 Acc: 0.8467
#
# Epoch 7/20
# ----------
# Train Loss: 0.8125 Acc: 0.7044
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 8/20
# ----------
# Train Loss: 0.8145 Acc: 0.7189
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 9/20
# ----------
# Train Loss: 0.8143 Acc: 0.7022
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 10/20
# ----------
# Train Loss: 0.8257 Acc: 0.7000
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 11/20
# ----------
# Train Loss: 0.8347 Acc: 0.6989
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 12/20
# ----------
# Train Loss: 0.8202 Acc: 0.7089
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 13/20
# ----------
# Train Loss: 0.8220 Acc: 0.7033
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 14/20
# ----------
# Train Loss: 0.8149 Acc: 0.7122
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 15/20
# ----------
# Train Loss: 0.8057 Acc: 0.7156
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 16/20
# ----------
# Train Loss: 0.8319 Acc: 0.7078
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 17/20
# ----------
# Train Loss: 0.8244 Acc: 0.7100
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch 18/20
# ----------
# Train Loss: 0.8400 Acc: 0.7133
# Val Loss: 0.4590 Acc: 0.8467
#
# Epoch
# Val Loss: 1.0381 Acc: 0.6115
#
# Epoch 9/20
# ----------
# Train Loss: 0.7618 Acc: 0.6990
# Val Loss: 1.0264 Acc: 0.6071
#
# Epoch 10/20
# ----------
# Train Loss: 0.7577 Acc: 0.6957
# Val Loss: 1.0466 Acc: 0.6071
#
# Epoch 11/20
# ----------
# Train Loss: 0.7463 Acc: 0.7269
# Val Loss: 1.0571 Acc: 0.5916
#
# Epoch 12/20
# ----------
# Train Loss: 0.7369 Acc: 0.7269
# Val Loss: 1.0411 Acc: 0.6159
#
# Epoch 13/20
# ----------
# Train Loss: 0.7098 Acc: 0.7358
# Val Loss: 1.0029 Acc: 0.6159
#
# Epoch 14/20
# ----------
# Train Loss: 0.6875 Acc: 0.7414
# Val Loss: 0.9913 Acc: 0.6159
#
# Epoch 15/20
# ----------
# Train Loss: 0.6752 Acc: 0.7648
# Val Loss: 0.9909 Acc: 0.6181
#
# Epoch 16/20
# ----------
# Train Loss: 0.6862 Acc: 0.7458
# Val Loss: 0.9912 Acc: 0.6181
#
# Epoch 17/20
# ----------
# Train Loss: 0.6719 Acc: 0.7581
# Val Loss: 0.9919 Acc: 0.6181
#
# Epoch 18/20
# ----------
# Train Loss: 0.6859 Acc: 0.7547
# Val Loss: 0.9930 Acc: 0.6181
#
# Epoch 19/20
# ----------
# Train Loss: 0.6851 Acc: 0.7458
# Val Loss: 0.9929 Acc: 0.6225
# Best model updated with Val Acc: 0.6225
#
# Epoch 20/20
# ----------
# Train Loss: 0.6831 Acc: 0.7369
# Val Loss: 0.9924 Acc: 0.6269
# Best model updated with Val Acc: 0.6269
#
# Training complete.
# Best Validation Accuracy: 0.6269
#
# Epoch 1/20
# ----------
# Train Loss: 0.8580 Acc: 0.6756
# Val Loss: 0.5731 Acc: 0.7800
# Best model updated with Val Acc: 0.7800
#
# Epoch 2/20
# ----------
# Train Loss: 0.8733 Acc: 0.6789
# Val Loss: 0.5730 Acc: 0.7800
#
# Epoch 3/20
# ----------
# Train Loss: 0.8473 Acc: 0.6889
# Val Loss: 0.5730 Acc: 0.7800
#
# Epoch 4/20
# ----------
# Train Loss: 0.8804 Acc: 0.6733
# Val Loss: 0.5730 Acc: 0.7800
#
# Epoch 5/20
# ----------
# Train Loss: 0.8697 Acc: 0.6844
# Val Loss: 0.5729 Acc: 0.7800
#
# Epoch 6/20
# ----------
# Train Loss: 0.8684 Acc: 0.6956
# Val Loss: 0.5729 Acc: 0.7800
#
# Epoch 7/20
# ----------
# Train Loss: 0.8774 Acc: 0.6822
# Val Loss: 0.5728 Acc: 0.7778
#
# Epoch 8/20
# ----------
# Train Loss: 0.8759 Acc: 0.6722
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch 9/20
# ----------
# Train Loss: 0.8743 Acc: 0.6833
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch 10/20
# ----------
# Train Loss: 0.8549 Acc: 0.6978
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch 11/20
# ----------
# Train Loss: 0.8511 Acc: 0.6978
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch 12/20
# ----------
# Train Loss: 0.8672 Acc: 0.6678
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch 13/20
# ----------
# Train Loss: 0.8656 Acc: 0.6833
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch 14/20
# ----------
# Train Loss: 0.8516 Acc: 0.6878
# Val Loss: 0.5728 Acc: 0.7800
#
# Epoch
# Best model updated with Val Acc: 0.7062
#
# Epoch 7/20
# ----------
# Train Loss: 0.4915 Acc: 0.8170
# Val Loss: 0.8831 Acc: 0.6825
#
# Epoch 8/20
# ----------
# Train Loss: 0.4287 Acc: 0.8489
# Val Loss: 0.7656 Acc: 0.7122
# Best model updated with Val Acc: 0.7122
#
# Epoch 9/20
# ----------
# Train Loss: 0.3737 Acc: 0.8770
# Val Loss: 0.7596 Acc: 0.7270
# Best model updated with Val Acc: 0.7270
#
# Epoch 10/20
# ----------
# Train Loss: 0.3487 Acc: 0.8881
# Val Loss: 0.7522 Acc: 0.7478
# Best model updated with Val Acc: 0.7478
#
# Epoch 11/20
# ----------
# Train Loss: 0.3270 Acc: 0.8859
# Val Loss: 0.7508 Acc: 0.7270
#
# Epoch 12/20
# ----------
# Train Loss: 0.3222 Acc: 0.8896
# Val Loss: 0.7561 Acc: 0.7211
#
# Epoch 13/20
# ----------
# Train Loss: 0.3228 Acc: 0.8822
# Val Loss: 0.7553 Acc: 0.7359
#
# Epoch 14/20
# ----------
# Train Loss: 0.3042 Acc: 0.8970
# Val Loss: 0.7499 Acc: 0.7270
#
# Epoch 15/20
# ----------
# Train Loss: 0.2923 Acc: 0.9015
# Val Loss: 0.7509 Acc: 0.7329
#
# Epoch 16/20
# ----------
# Train Loss: 0.3063 Acc: 0.8970
# Val Loss: 0.7517 Acc: 0.7329
#
# Epoch 17/20
# ----------
# Train Loss: 0.2940 Acc: 0.9081
# Val Loss: 0.7533 Acc: 0.7329
#
# Epoch 18/20
# ----------
# Train Loss: 0.2995 Acc: 0.9015
# Val Loss: 0.7540 Acc: 0.7329
#
# Epoch 19/20
# ----------
# Train Loss: 0.2857 Acc: 0.9074
# Val Loss: 0.7552 Acc: 0.7359
#
# Epoch 20/20
# ----------
# Train Loss: 0.2848 Acc: 0.9104
# Val Loss: 0.7553 Acc: 0.7359
#
# Training complete.
# Best Validation Accuracy: 0.7478
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.6784 Acc: 0.3374
# Val Loss: 1.3396 Acc: 0.5077
# Best model updated with Val Acc: 0.5077
#
# Epoch 2/20
# ----------
# Train Loss: 1.1799 Acc: 0.5780
# Val Loss: 1.2155 Acc: 0.5430
# Best model updated with Val Acc: 0.5430
#
# Epoch 3/20
# ----------
# Train Loss: 1.0094 Acc: 0.6203
# Val Loss: 1.1449 Acc: 0.6115
# Best model updated with Val Acc: 0.6115
#
# Epoch 4/20
# ----------
# Train Loss: 0.8965 Acc: 0.6615
# Val Loss: 1.0517 Acc: 0.5982
#
# Epoch 5/20
# ----------
# Train Loss: 0.8397 Acc: 0.6849
# Val Loss: 1.0505 Acc: 0.6071
#
# Epoch 6/20
# ----------
# Train Loss: 0.7227 Acc: 0.7383
# Val Loss: 1.0267 Acc: 0.6534
# Best model updated with Val Acc: 0.6534
#
# Epoch 7/20
# ----------
# Train Loss: 0.6122 Acc: 0.7840
# Val Loss: 1.0262 Acc: 0.6225
#
# Epoch 8/20
# ----------
# Train Loss: 0.5492 Acc: 0.7918
# Val Loss: 0.9922 Acc: 0.6512
# Best model updated with Val Acc: 0.6600
#
# Epoch 9/20
# ----------
# Train Loss: 0.5895 Acc: 0.7895
# Val Loss: 0.9459 Acc: 0.6755
# Best model updated with Val Acc: 0.6755
#
# Epoch 10/20
# ----------
# Train Loss: 0.5631 Acc: 0.7918
# Val Loss: 0.9396 Acc: 0.6755
#
# Epoch 11/20
# ----------
# Train Loss: 0.5477 Acc: 0.8096
# Val Loss: 0.9390 Acc: 0.6821
# Best model updated with Val Acc: 0.6821
#
# Epoch 12/20
# ----------
# Train Loss: 0.5387 Acc: 0.8096
# Val Loss: 0.9385 Acc: 0.6777
#
# Epoch 13/20
# ----------
# Train Loss: 0.5313 Acc: 0.8073
# Val Loss: 0.9498 Acc: 0.6689
#
# Epoch 14/20
# ----------
# Train Loss: 0.5373 Acc: 0.8018
# Val Loss: 0.9836 Acc: 0.6490
#
# Epoch 15/20
# ----------
# Train Loss: 0.5428 Acc: 0.7895
# Val Loss: 0.9791 Acc: 0.6512
#
# Epoch 16/20
# ----------
# Train Loss: 0.5287 Acc: 0.7984
# Val Loss: 0.9748 Acc: 0.6512
#
# Epoch 17/20
# ----------
# Train Loss: 0.5085 Acc: 0.8174
# Val Loss: 0.9687 Acc: 0.6578
#
# Epoch 18/20
# ----------
# Train Loss: 0.5195 Acc: 0.8018
# Val Loss: 0.9610 Acc: 0.6623
#
# Epoch 19/20
# ----------
# Train Loss: 0.5112 Acc: 0.8118
# Val Loss: 0.9543 Acc: 0.6623
#
# Epoch 20/20
# ----------
# Train Loss: 0.5032 Acc: 0.7984
# Val Loss: 0.9464 Acc: 0.6689
#
# Training complete.
# Best Validation Accuracy: 0.6821
#
# Epoch 1/20
# ----------
# Train Loss: 0.7516 Acc: 0.7322
# Val Loss: 0.4420 Acc: 0.8492
# Best model updated with Val Acc: 0.8492
#
# Epoch 2/20
# ----------
# Train Loss: 0.7497 Acc: 0.7456
# Val Loss: 0.4419 Acc: 0.8470
#
# Epoch 3/20
# ----------
# Train Loss: 0.7421 Acc: 0.7522
# Val Loss: 0.4417 Acc: 0.8470
#
# Epoch 4/20
# ----------
# Train Loss: 0.7418 Acc: 0.7478
# Val Loss: 0.4414 Acc: 0.8470
#
# Epoch 5/20
# ----------
# Train Loss: 0.7266 Acc: 0.7478
# Val Loss: 0.4414 Acc: 0.8492
#
# Epoch 6/20
# ----------
# Train Loss: 0.7162 Acc: 0.7433
# Val Loss: 0.4414 Acc: 0.8492
#
# Epoch 7/20
# ----------
# Train Loss: 0.7249 Acc: 0.7611
# Val Loss: 0.4414 Acc: 0.8492
#
# Epoch 8/20
# ----------
# Train Loss: 0.7288 Acc: 0.7444
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch 9/20
# ----------
# Train Loss: 0.7204 Acc: 0.7456
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch 10/20
# ----------
# Train Loss: 0.7504 Acc: 0.7400
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch 11/20
# ----------
# Train Loss: 0.7178 Acc: 0.7344
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch 12/20
# ----------
# Train Loss: 0.7441 Acc: 0.7333
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch 13/20
# ----------
# Train Loss: 0.7261 Acc: 0.7389
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch 14/20
# ----------
# Train Loss: 0.7106 Acc: 0.7533
# Val Loss: 0.4413 Acc: 0.8492
#
# Epoch
#
# Epoch 4/20
# ----------
# Train Loss: 0.9946 Acc: 0.6285
# Val Loss: 1.0385 Acc: 0.5752
# Best model updated with Val Acc: 0.5752
#
# Epoch 5/20
# ----------
# Train Loss: 0.8688 Acc: 0.6763
# Val Loss: 0.9985 Acc: 0.5885
# Best model updated with Val Acc: 0.5885
#
# Epoch 6/20
# ----------
# Train Loss: 0.8023 Acc: 0.6974
# Val Loss: 1.0197 Acc: 0.6106
# Best model updated with Val Acc: 0.6106
#
# Epoch 7/20
# ----------
# Train Loss: 0.7099 Acc: 0.7486
# Val Loss: 1.0279 Acc: 0.6195
# Best model updated with Val Acc: 0.6195
#
# Epoch 8/20
# ----------
# Train Loss: 0.7278 Acc: 0.7386
# Val Loss: 0.9689 Acc: 0.6195
#
# Epoch 9/20
# ----------
# Train Loss: 0.6104 Acc: 0.7831
# Val Loss: 0.9690 Acc: 0.6261
# Best model updated with Val Acc: 0.6261
#
# Epoch 10/20
# ----------
# Train Loss: 0.6162 Acc: 0.7764
# Val Loss: 0.9485 Acc: 0.6416
# Best model updated with Val Acc: 0.6416
#
# Epoch 11/20
# ----------
# Train Loss: 0.5599 Acc: 0.8087
# Val Loss: 0.9251 Acc: 0.6482
# Best model updated with Val Acc: 0.6482
#
# Epoch 12/20
# ----------
# Train Loss: 0.5314 Acc: 0.8131
# Val Loss: 0.9236 Acc: 0.6504
# Best model updated with Val Acc: 0.6504
#
# Epoch 13/20
# ----------
# Train Loss: 0.5515 Acc: 0.8087
# Val Loss: 0.9356 Acc: 0.6549
# Best model updated with Val Acc: 0.6549
#
# Epoch 14/20
# ----------
# Train Loss: 0.5447 Acc: 0.8109
# Val Loss: 0.9545 Acc: 0.6482
#
# Epoch 15/20
# ----------
# Train Loss: 0.5199 Acc: 0.8098
# Val Loss: 0.9530 Acc: 0.6416
#
# Epoch 16/20
# ----------
# Train Loss: 0.5262 Acc: 0.8120
# Val Loss: 0.9485 Acc: 0.6438
#
# Epoch 17/20
# ----------
# Train Loss: 0.5225 Acc: 0.8065
# Val Loss: 0.9432 Acc: 0.6394
#
# Epoch 18/20
# ----------
# Train Loss: 0.5247 Acc: 0.8187
# Val Loss: 0.9392 Acc: 0.6416
#
# Epoch 19/20
# ----------
# Train Loss: 0.5272 Acc: 0.8109
# Val Loss: 0.9359 Acc: 0.6416
#
# Epoch 20/20
# ----------
# Train Loss: 0.5349 Acc: 0.8065
# Val Loss: 0.9334 Acc: 0.6416
#
# Training complete.
# Best Validation Accuracy: 0.6549
#
# Epoch 1/20
# ----------
# Train Loss: 0.7706 Acc: 0.7233
# Val Loss: 0.4156 Acc: 0.8847
# Best model updated with Val Acc: 0.8847
#
# Epoch 2/20
# ----------
# Train Loss: 0.7405 Acc: 0.7411
# Val Loss: 0.4155 Acc: 0.8847
#
# Epoch 3/20
# ----------
# Train Loss: 0.7252 Acc: 0.7400
# Val Loss: 0.4155 Acc: 0.8847
#
# Epoch 4/20
# ----------
# Train Loss: 0.7270 Acc: 0.7367
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.8337 Acc: 0.2714
# Val Loss: 1.4878 Acc: 0.4381
# Best model updated with Val Acc: 0.4381
#
# Epoch 2/20
# ----------
# Train Loss: 1.4611 Acc: 0.4394
# Val Loss: 1.2587 Acc: 0.5465
# Best model updated with Val Acc: 0.5465
#
# Epoch 3/20
# ----------
# Train Loss: 1.2441 Acc: 0.5439
# Val Loss: 1.1650 Acc: 0.5354
#
# Epoch 4/20
# ----------
# Train Loss: 1.1694 Acc: 0.5662
# Val Loss: 1.1079 Acc: 0.5531
# Best model updated with Val Acc: 0.5531
#
# Epoch 5/20
# ----------
# Train Loss: 1.0618 Acc: 0.5984
# Val Loss: 1.0546 Acc: 0.6018
# Best model updated with Val Acc: 0.6018
#
# Epoch 6/20
# ----------
# Train Loss: 0.9722 Acc: 0.6452
# Val Loss: 1.0587 Acc: 0.5841
#
# Epoch 7/20
# ----------
# Train Loss: 0.8923 Acc: 0.6563
# Val Loss: 1.0471 Acc: 0.5907
#
# Epoch 8/20
# ----------
# Train Loss: 0.8850 Acc: 0.6685
# Val Loss: 0.9910 Acc: 0.6018
#
# Epoch 9/20
# ----------
# Train Loss: 0.8283 Acc: 0.7030
# Val Loss: 0.9612 Acc: 0.6040
# Best model updated with Val Acc: 0.6040
#
# Epoch 10/20
# ----------
# Train Loss: 0.7900 Acc: 0.7075
# Val Loss: 0.9556 Acc: 0.6128
# Best model updated with Val Acc: 0.6128
#
# Epoch 11/20
# ----------
# Train Loss: 0.7594 Acc: 0.7152
# Val Loss: 0.9470 Acc: 0.6150
# Best model updated with Val Acc: 0.6150
#
# Epoch 12/20
# ----------
# Train Loss: 0.7759 Acc: 0.7264
# Val Loss: 0.9393 Acc: 0.6173
# Best model updated with Val Acc: 0.6173
#
# Epoch 13/20
# ----------
# Train Loss: 0.7664 Acc: 0.7130
# Val Loss: 0.9353 Acc: 0.6195
# Best model updated with Val Acc: 0.6195
#
# Epoch 14/20
# ----------
# Train Loss: 0.7566 Acc: 0.7175
# Val Loss: 0.9383 Acc: 0.6261
# Best model updated with Val Acc: 0.6261
#
# Epoch 15/20
# ----------
# Train Loss: 0.7448 Acc: 0.7341
# Val Loss: 0.9395 Acc: 0.6327
# Best model updated with Val Acc: 0.6327
#
# Epoch 16/20
# ----------
# Train Loss: 0.7654 Acc: 0.7119
# Val Loss: 0.9398 Acc: 0.6372
# Best model updated with Val Acc: 0.6372
#
# Epoch 17/20
# ----------
# Train Loss: 0.7541 Acc: 0.7130
# Val Loss: 0.9397 Acc: 0.6372
#
# Epoch 18/20
# ----------
# Train Loss: 0.7467 Acc: 0.7286
# Val Loss: 0.9387 Acc: 0.6239
#
# Epoch 19/20
# ----------
# Train Loss: 0.7587 Acc: 0.7319
# Val Loss: 0.9379 Acc: 0.6217
#
# Epoch 20/20
# ----------
# Train Loss: 0.7456 Acc: 0.7308
# Val Loss: 0.9373 Acc: 0.6217
#
# Training complete.
# Best Validation Accuracy: 0.6372
#
# Epoch 1/20
# ----------
# Train Loss: 0.8961 Acc: 0.6711
# Val Loss: 0.6462 Acc: 0.7783
# Best model updated with Val Acc: 0.7783
#
# Epoch 2/20
# ----------
# Train Loss: 0.8727 Acc: 0.6800
# Val Loss: 0.6461 Acc: 0.7783
#
# Epoch 3/20
# ----------
# Train Loss: 0.8821 Acc: 0.6744
# Val Loss: 0.6461 Acc: 0.7783
#
# Epoch 4/20
# ----------
# Train Loss: 0.8869 Acc: 0.6689
# Val Loss: 0.6460 Acc: 0.7783
#
# Epoch 5/20
# ----------
# Train Loss: 0.8632 Acc: 0.6889
# Val Loss: 0.6460 Acc: 0.7783
#
# Epoch 6/20
# ----------
# Train Loss: 0.8643 Acc: 0.6833
# Val Loss: 0.6460 Acc: 0.7783
#
# Epoch 7/20
# ----------
# Train Loss: 0.8745 Acc: 0.6733
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 8/20
# ----------
# Train Loss: 0.8655 Acc: 0.6800
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 9/20
# ----------
# Train Loss: 0.8789 Acc: 0.6667
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 10/20
# ----------
# Train Loss: 0.8573 Acc: 0.6789
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 11/20
# ----------
# Train Loss: 0.8711 Acc: 0.6778
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 12/20
# ----------
# Train Loss: 0.8792 Acc: 0.6767
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 13/20
# ----------
# Train Loss: 0.8983 Acc: 0.6667
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 14/20
# ----------
# Train Loss: 0.8916 Acc: 0.6833
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 15/20
# ----------
# Train Loss: 0.8635 Acc: 0.6700
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 16/20
# ----------
# Train Loss: 0.8586 Acc: 0.6889
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 17/20
# ----------
# Train Loss: 0.8893 Acc: 0.6756
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 18/20
# ----------
# Train Loss: 0.8880 Acc: 0.6778
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 19/20
# ----------
# Train Loss: 0.8769 Acc: 0.6911
# Val Loss: 0.6459 Acc: 0.7783
#
# Epoch 20/20
# ----------
# Train Loss: 0.8745 Acc: 0.6767
# Val Loss: 0.6459 Acc: 0.7783
#
# Training complete.
# Best Validation Accuracy: 0.7783
#
# Epoch 1/20
# ----------
# Train Loss: 0.9270 Acc: 0.6578
# Val Loss: 0.6017 Acc: 0.7969
# Best model updated with Val Acc: 0.7969
#
# Epoch 2/20
# ----------
# Train Loss: 0.8746 Acc: 0.6744
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 3/20
# ----------
# Train Loss: 0.9163 Acc: 0.6578
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 4/20
# ----------
# Train Loss: 0.9216 Acc: 0.6567
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 5/20
# ----------
# Train Loss: 0.8855 Acc: 0.6589
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 6/20
# ----------
# Train Loss: 0.8814 Acc: 0.6777
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 7/20
# ----------
# Train Loss: 0.9146 Acc: 0.6334
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 8/20
# ----------
# Train Loss: 0.8927 Acc: 0.6622
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 9/20
# ----------
# Train Loss: 0.9021 Acc: 0.6589
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 10/20
# ----------
# Train Loss: 0.9088 Acc: 0.6556
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 11/20
# ----------
# Train Loss: 0.9012 Acc: 0.6744
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 12/20
# ----------
# Train Loss: 0.8663 Acc: 0.6899
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 13/20
# ----------
# Train Loss: 0.9031 Acc: 0.6600
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 14/20
# ----------
# Train Loss: 0.8891 Acc: 0.6755
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 15/20
# ----------
# Train Loss: 0.8683 Acc: 0.6578
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 16/20
# ----------
# Train Loss: 0.8884 Acc: 0.6611
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 17/20
# ----------
# Train Loss: 0.8962 Acc: 0.6777
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 18/20
# ----------
# Train Loss: 0.8822 Acc: 0.6711
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 19/20
# ----------
# Train Loss: 0.8985 Acc: 0.6611
# Val Loss: 0.6017 Acc: 0.7969
#
# Epoch 20/20
# ----------
# Train Loss: 0.8785 Acc: 0.6822
# Val Loss: 0.6017 Acc: 0.7969
#
# Training complete.
# Best Validation Accuracy: 0.7969
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 1.6309 Acc: 0.3871
# Val Loss: 1.2953 Acc: 0.5476
# Best model updated with Val Acc: 0.5476
#
# Epoch 2/20
# ----------
# Train Loss: 1.1369 Acc: 0.5751
# Val Loss: 1.0579 Acc: 0.6042
# Best model updated with Val Acc: 0.6042
#
# Epoch 3/20
# ----------
# Train Loss: 0.9357 Acc: 0.6432
# Val Loss: 0.9592 Acc: 0.6429
# Best model updated with Val Acc: 0.6429
#
# Epoch 4/20
# ----------
# Train Loss: 0.8043 Acc: 0.7061
# Val Loss: 0.8920 Acc: 0.6875
# Best model updated with Val Acc: 0.6875
#
# Epoch 5/20
# ----------
# Train Loss: 0.6733 Acc: 0.7498
# Val Loss: 0.8161 Acc: 0.6935
# Best model updated with Val Acc: 0.6935
#
# Epoch 6/20
# ----------
# Train Loss: 0.5856 Acc: 0.7942
# Val Loss: 0.8512 Acc: 0.7024
# Best model updated with Val Acc: 0.7024
#
# Epoch 7/20
# ----------
# Train Loss: 0.5237 Acc: 0.8113
# Val Loss: 0.9261 Acc: 0.6964
#
# Epoch 8/20
# ----------
# Train Loss: 0.4451 Acc: 0.8446
# Val Loss: 0.8151 Acc: 0.7113
# Best model updated with Val Acc: 0.7113
#
# Epoch 9/20
# ----------
# Train Loss: 0.4001 Acc: 0.8579
# Val Loss: 0.8243 Acc: 0.7143
# Best model updated with Val Acc: 0.7143
#
# Epoch 10/20
# ----------
# Train Loss: 0.3998 Acc: 0.8505
# Val Loss: 0.8331 Acc: 0.7351
# Best model updated with Val Acc: 0.7351
#
# Epoch 11/20
# ----------
# Train Loss: 0.3920 Acc: 0.8616
# Val Loss: 0.8313 Acc: 0.7321
#
# Epoch 12/20
# ----------
# Train Loss: 0.3968 Acc: 0.8601
# Val Loss: 0.8376 Acc: 0.7143
#
# Epoch 13/20
# ----------
# Train Loss: 0.3590 Acc: 0.8712
# Val Loss: 0.8460 Acc: 0.7321
#
# Epoch 14/20
# ----------
# Train Loss: 0.3559 Acc: 0.8727
# Val Loss: 0.8331 Acc: 0.6964
#
# Epoch 15/20
# ----------
# Train Loss: 0.3518 Acc: 0.8801
# Val Loss: 0.8337 Acc: 0.6964
#
# Epoch 16/20
# ----------
# Train Loss: 0.3684 Acc: 0.8653
# Val Loss: 0.8347 Acc: 0.7113
#
# Epoch 17/20
# ----------
# Train Loss: 0.3381 Acc: 0.8823
# Val Loss: 0.8370 Acc: 0.7232
#
# Epoch 18/20
# ----------
# Train Loss: 0.3458 Acc: 0.8749
# Val Loss: 0.8373 Acc: 0.7202
#
# Epoch 19/20
# ----------
# Train Loss: 0.3317 Acc: 0.8860
# Val Loss: 0.8375 Acc: 0.7262
#
# Epoch 20/20
# ----------
# Train Loss: 0.3379 Acc: 0.8868
# Val Loss: 0.8387 Acc: 0.7262
#
# Training complete.
# Best Validation Accuracy: 0.7351

# %%
hyper_tuning_result
# Out:
# [({'dr': 0.6}, tensor(0.7135, dtype=torch.float64)),
#  ({'dr': 0.5}, tensor(0.7478, dtype=torch.float64)),
#  ({'dr': 0.5}, tensor(0.7292, dtype=torch.float64)),
#  ({'dr': 0.5}, tensor(0.6815, dtype=torch.float64)),
#  ({'dr': 0.6}, tensor(0.7351, dtype=torch.float64))]

# %%
def run_epoch_with_prediction(model, optimizer, criterion, scheduler, train_loader, test_loader, fold_idx):
  RESULT_SAVE_DIR = 'drive/MyDrive/Alexnet_Result'  # Directory to save results
  best_acc = 0.0
  num_epochs = 20

  epoch_train_acc = []
  epoch_train_loss = []
  epoch_val_acc = []
  epoch_val_loss = []
  epoch_idx = []

  for epoch in range(num_epochs):
      print(f'\nEpoch {epoch+1}/{num_epochs}')
      print('-' * 10)

      # Training Phase
      train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, DEVICE)
      print(f'Train Loss: {train_loss:.4f} Acc: {train_acc:.4f}')

      # Validation Phase
      val_loss, val_acc = eval_epoch(model, test_loader, criterion, DEVICE)
      print(f'Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}')

      epoch_train_acc.append(train_acc)
      epoch_train_loss.append(train_loss)
      epoch_val_acc.append(val_acc)
      epoch_val_loss.append(val_loss)
      epoch_idx.append(epoch)

      # Check if this is the best model so far
      if val_acc > best_acc:
          best_acc = val_acc

      # Step the scheduler
      scheduler.step()

  print('\nTraining complete.')
  print(f'Best Validation Accuracy: {best_acc:.4f}')

  epoch_df = pd.DataFrame({'Epoch': epoch_idx, 'Train_Acc': epoch_train_acc, 'Train_Loss': epoch_train_loss,
                           'Val_Acc': epoch_val_acc, 'Val_Loss': epoch_val_loss})
  epoch_file_name = f"drive/MyDrive/Alexnet_Result/fold{fold_idx+1}_epochs.csv"
  epoch_df.to_csv(epoch_file_name, index=False)
  print(f"Fold {fold_idx+1} epochs train/val metrics saved to {epoch_file_name}")

  model.eval()
  predictions = []
  actuals = []
  with torch.no_grad():
      for images, labels in test_loader:
          images = images.to(DEVICE)
          outputs = model(images)
          _, preds = torch.max(outputs, 1)
          predictions.extend(preds.cpu().numpy())
          actuals.extend(labels.cpu().numpy())

  result_df = pd.DataFrame({'Prediction': predictions, 'Actual': actuals})
  file_name = f"{RESULT_SAVE_DIR}/fold{fold_idx+1}.csv"
  result_df.to_csv(file_name, index=False)
  print(f"Fold {fold_idx+1} predictions saved to {file_name}")

  return model, best_acc

# %%
def cross_validate_20_fold(X, y, param):
    MODEL_SAVE_DIR = 'drive/MyDrive/Alexnet_Model'  # Directory to save models
    fold = stratifiedKFold(n_split=5, shuffle=True, random_state=42)
    fold_results = []

    best_acc = 0.0

    dropout_rate = param

    for fold_idx, (train_idx, test_idx) in enumerate(fold.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        model, criterion, optimizer, scheduler = alexnet(dropout_rate)

        # Create Datasets for outer folds
        train_dataset = SkinCancerDataset(X_train, IMAGE_DIRS, MASK_DIR, transform=train_transform)
        test_dataset = SkinCancerDataset(X_test, IMAGE_DIRS, MASK_DIR, transform=val_test_transform)

        # Create DataLoaders for outer folds
        BATCH_SIZE = 128
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
        test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

        model, val_acc = run_epoch_with_prediction(model, optimizer, criterion, scheduler, train_loader, test_loader, fold_idx)

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_path = os.path.join(MODEL_SAVE_DIR, 'best_model.pth')
            torch.save(model.state_dict, best_model_path)
            print(f"New best model saved from Fold {fold_idx+1} with validation accuracy: {val_acc:.4f}")

        fold_results.append((fold_idx+1, best_acc))

    return fold_results

# %%
file_path = 'drive/MyDrive/hyper_result.csv'
hyper_tuning_result = pd.read_csv(file_path)

# %%
mean_dr = hyper_tuning_result.groupby('dr')['accuracy'].mean().reset_index()
best_dr = mean_dr.loc[mean_dr['accuracy'].idxmax(), 'dr']
best_dr
# Out:
# 0.6

# %%
fold_result = cross_validate_20_fold(metadata, metadata['dx_encoded'], best_dr)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Epoch 1/20
# ----------
# Train Loss: 0.8365 Acc: 0.7002
# Val Loss: 0.6500 Acc: 0.7616
#
# Epoch 2/20
# ----------
# Train Loss: 0.6300 Acc: 0.7695
# Val Loss: 0.6004 Acc: 0.7661
#
# Epoch 3/20
# ----------
# Train Loss: 0.5395 Acc: 0.7949
# Val Loss: 0.5368 Acc: 0.7995
#
# Epoch 4/20
# ----------
# Train Loss: 0.4854 Acc: 0.8180
# Val Loss: 0.5149 Acc: 0.7950
#
# Epoch 5/20
# ----------
# Train Loss: 0.4347 Acc: 0.8403
# Val Loss: 0.4894 Acc: 0.8190
#
# Epoch 6/20
# ----------
# Train Loss: 0.4012 Acc: 0.8512
# Val Loss: 0.4691 Acc: 0.8219
#
# Epoch 7/20
# ----------
# Train Loss: 0.3541 Acc: 0.8665
# Val Loss: 0.4650 Acc: 0.8274
#
# Epoch 8/20
# ----------
# Train Loss: 0.2863 Acc: 0.8976
# Val Loss: 0.4366 Acc: 0.8339
#
# Epoch 9/20
# ----------
# Train Loss: 0.2603 Acc: 0.9012
# Val Loss: 0.4288 Acc: 0.8384
#
# Epoch 10/20
# ----------
# Train Loss: 0.2477 Acc: 0.9089
# Val Loss: 0.4269 Acc: 0.8394
#
# Epoch 11/20
# ----------
# Train Loss: 0.2415 Acc: 0.9126
# Val Loss: 0.4317 Acc: 0.8429
#
# Epoch 12/20
# ----------
# Train Loss: 0.2356 Acc: 0.9112
# Val Loss: 0.4314 Acc: 0.8444
#
# Epoch 13/20
# ----------
# Train Loss: 0.2292 Acc: 0.9149
# Val Loss: 0.4359 Acc: 0.8379
#
# Epoch 14/20
# ----------
# Train Loss: 0.2301 Acc: 0.9155
# Val Loss: 0.4341 Acc: 0.8434
#
# Epoch 15/20
# ----------
# Train Loss: 0.2138 Acc: 0.9226
# Val Loss: 0.4316 Acc: 0.8454
#
# Epoch 16/20
# ----------
# Train Loss: 0.2115 Acc: 0.9221
# Val Loss: 0.4314 Acc: 0.8444
#
# Epoch 17/20
# ----------
# Train Loss: 0.2046 Acc: 0.9226
# Val Loss: 0.4316 Acc: 0.8449
#
# Epoch 18/20
# ----------
# Train Loss: 0.2104 Acc: 0.9217
# Val Loss: 0.4323 Acc: 0.8444
#
# Epoch 19/20
# ----------
# Train Loss: 0.2094 Acc: 0.9237
# Val Loss: 0.4325 Acc: 0.8444
#
# Epoch 20/20
# ----------
# Train Loss: 0.2074 Acc: 0.9222
# Val Loss: 0.4325 Acc: 0.8434
#
# Training complete.
# Best Validation Accuracy: 0.8454
# Fold 1 epochs train/val metrics saved to drive/MyDrive/Alexnet_Result/fold1_epochs.csv
# Fold 1 predictions saved to drive/MyDrive/Alexnet_Result/fold1.csv
# New best model saved from Fold 1 with validation accuracy: 0.8454
#
# Epoch 1/20
# ----------
# Train Loss: 0.2828 Acc: 0.8993
# Val Loss: 0.1451 Acc: 0.9506
#
# Epoch 2/20
# ----------
# Train Loss: 0.2815 Acc: 0.9002
# Val Loss: 0.1452 Acc: 0.9506
#
# Epoch 3/20
# ----------
# Train Loss: 0.2728 Acc: 0.9026
# Val Loss: 0.1456 Acc: 0.9506
#
# Epoch 4/20
# ----------
# Train Loss: 0.2759 Acc: 0.9037
# Val Loss: 0.1456 Acc: 0.9506
#
# Epoch 5/20
# ----------
# Train Loss: 0.2754 Acc: 0.9032
# Val Loss: 0.1459 Acc: 0.9496
#
# Epoch 6/20
# ----------
# Train Loss: 0.2777 Acc: 0.8986
# Val Loss: 0.1460 Acc: 0.9496
#
# Epoch 7/20
# ----------
# Train Loss: 0.2773 Acc: 0.9019
# Val Loss: 0.1463 Acc: 0.9496
#
# Epoch 8/20
# ----------
# Train Loss: 0.2768 Acc: 0.9019
# Val Loss: 0.1461 Acc: 0.9501
#
# Epoch 9/20
# ----------
# Train Loss: 0.2724 Acc: 0.9042
# Val Loss: 0.1461 Acc: 0.9501
#
# Epoch 10/20
# ----------
# Train Loss: 0.2809 Acc: 0.9019
# Val Loss: 0.1462 Acc: 0.9501
#
# Epoch 11/20
# ----------
# Train Loss: 0.2840 Acc: 0.9014
# Val Loss: 0.1462 Acc: 0.9501
#
# Epoch 12/20
# ----------
# Train Loss: 0.2761 Acc: 0.9041
# Val Loss: 0.1462 Acc: 0.9501
#
# Epoch 13/20
# ----------
# Train Loss: 0.2766 Acc: 0.9012
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 14/20
# ----------
# Train Loss: 0.2761 Acc: 0.9015
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 15/20
# ----------
# Train Loss: 0.2746 Acc: 0.9066
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 16/20
# ----------
# Train Loss: 0.2787 Acc: 0.9034
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 17/20
# ----------
# Train Loss: 0.2783 Acc: 0.9001
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 18/20
# ----------
# Train Loss: 0.2683 Acc: 0.9047
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 19/20
# ----------
# Train Loss: 0.2775 Acc: 0.9030
# Val Loss: 0.1463 Acc: 0.9501
#
# Epoch 20/20
# ----------
# Train Loss: 0.2753 Acc: 0.9021
# Val Loss: 0.1463 Acc: 0.9501
#
# Training complete.
# Best Validation Accuracy: 0.9506
# Fold 2 epochs train/val metrics saved to drive/MyDrive/Alexnet_Result/fold2_epochs.csv
# Fold 2 predictions saved to drive/MyDrive/Alexnet_Result/fold2.csv
# New best model saved from Fold 2 with validation accuracy: 0.9506
#
# Epoch 1/20
# ----------
# Train Loss: 0.2732 Acc: 0.9056
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 2/20
# ----------
# Train Loss: 0.2694 Acc: 0.9038
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 3/20
# ----------
# Train Loss: 0.2789 Acc: 0.9011
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 4/20
# ----------
# Train Loss: 0.2733 Acc: 0.9049
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 5/20
# ----------
# Train Loss: 0.2686 Acc: 0.9065
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 6/20
# ----------
# Train Loss: 0.2702 Acc: 0.9024
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 7/20
# ----------
# Train Loss: 0.2749 Acc: 0.9049
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 8/20
# ----------
# Train Loss: 0.2746 Acc: 0.9053
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 9/20
# ----------
# Train Loss: 0.2720 Acc: 0.9026
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 10/20
# ----------
# Train Loss: 0.2679 Acc: 0.9050
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 11/20
# ----------
# Train Loss: 0.2694 Acc: 0.9074
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 12/20
# ----------
# Train Loss: 0.2780 Acc: 0.8994
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 13/20
# ----------
# Train Loss: 0.2772 Acc: 0.9003
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 14/20
# ----------
# Train Loss: 0.2762 Acc: 0.9024
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 15/20
# ----------
# Train Loss: 0.2759 Acc: 0.9026
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 16/20
# ----------
# Train Loss: 0.2718 Acc: 0.9055
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 17/20
# ----------
# Train Loss: 0.2748 Acc: 0.9015
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 18/20
# ----------
# Train Loss: 0.2767 Acc: 0.9031
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 19/20
# ----------
# Train Loss: 0.2731 Acc: 0.9041
# Val Loss: 0.1517 Acc: 0.9521
#
# Epoch 20/20
# ----------
# Train Loss: 0.2725 Acc: 0.9028
# Val Loss: 0.1517 Acc: 0.9521
#
# Training complete.
# Best Validation Accuracy: 0.9521
# Fold 3 epochs train/val metrics saved to drive/MyDrive/Alexnet_Result/fold3_epochs.csv
# Fold 3 predictions saved to drive/MyDrive/Alexnet_Result/fold3.csv
# New best model saved from Fold 3 with validation accuracy: 0.9521
#
# Epoch 1/20
# ----------
# Train Loss: 0.2707 Acc: 0.9042
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 2/20
# ----------
# Train Loss: 0.2783 Acc: 0.9012
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 3/20
# ----------
# Train Loss: 0.2793 Acc: 0.9008
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 4/20
# ----------
# Train Loss: 0.2735 Acc: 0.9042
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 5/20
# ----------
# Train Loss: 0.2759 Acc: 0.8978
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 6/20
# ----------
# Train Loss: 0.2758 Acc: 0.9012
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 7/20
# ----------
# Train Loss: 0.2706 Acc: 0.9015
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 8/20
# ----------
# Train Loss: 0.2733 Acc: 0.9007
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 9/20
# ----------
# Train Loss: 0.2736 Acc: 0.9034
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 10/20
# ----------
# Train Loss: 0.2793 Acc: 0.8970
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 11/20
# ----------
# Train Loss: 0.2758 Acc: 0.9019
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 12/20
# ----------
# Train Loss: 0.2690 Acc: 0.9049
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 13/20
# ----------
# Train Loss: 0.2767 Acc: 0.9007
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 14/20
# ----------
# Train Loss: 0.2723 Acc: 0.9047
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 15/20
# ----------
# Train Loss: 0.2755 Acc: 0.9024
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 16/20
# ----------
# Train Loss: 0.2774 Acc: 0.9008
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 17/20
# ----------
# Train Loss: 0.2701 Acc: 0.9039
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 18/20
# ----------
# Train Loss: 0.2770 Acc: 0.8994
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 19/20
# ----------
# Train Loss: 0.2781 Acc: 0.9009
# Val Loss: 0.1436 Acc: 0.9605
#
# Epoch 20/20
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-d2140eff5db5> in <cell line: 1>()
# ----> 1 fold_result = cross_validate_20_fold(metadata, metadata['dx_encoded'], best_dr)
#
# <ipython-input-27-85cf3000a298> in cross_validate_20_fold(X, y, param)
#      22         test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
#      23
# ---> 24         model, val_acc = run_epoch_with_prediction(model, optimizer, criterion, scheduler, train_loader, test_loader, fold_idx)
#      25
#      26         if val_acc > best_acc:
#
# <ipython-input-23-23ea5884182f> in run_epoch_with_prediction(model, optimizer, criterion, scheduler, train_loader, test_loader, fold_idx)
#      15
#      16       # Training Phase
# ---> 17       train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, DEVICE)
#      18       print(f'Train Loss: {train_loss:.4f} Acc: {train_acc:.4f}')
#      19
#
# <ipython-input-15-61f15a98718d> in train_epoch(model, dataloader, optimizer, criterion, device)
#       5     total = 0
#       6
# ----> 7     for inputs, labels in dataloader:
#       8         inputs = inputs.to(device)
#       9         labels = labels.to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     671     def _next_data(self):
#     672         index = self._next_index()  # may raise StopIteration
# --> 673         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674         if self._pin_memory:
#     675             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-13-6ef389b9817f> in __getitem__(self, idx)
#      49         # Apply transformations and masking to the image
#      50         if self.transform:
# ---> 51             augmented = self.transform(image=image, mask=mask)
#      52             image = augmented['image']
#      53             mask = augmented['mask']
#
# /usr/local/lib/python3.10/dist-packages/albumentations/core/composition.py in __call__(self, force_apply, *args, **data)
#     346
#     347         for t in self.transforms:
# --> 348             data = t(**data)
#     349             data = self.check_data_post_transform(data)
#     350
#
# /usr/local/lib/python3.10/dist-packages/albumentations/core/transforms_interface.py in __call__(self, force_apply, *args, **kwargs)
#     122             if self.deterministic:
#     123                 kwargs[self.save_key][id(self)] = deepcopy(params)
# --> 124             return self.apply_with_params(params, **kwargs)
#     125
#     126         return kwargs
#
# /usr/local/lib/python3.10/dist-packages/albumentations/core/transforms_interface.py in apply_with_params(self, params, *args, **kwargs)
#     141                 target_function = self._key2func[key]
#     142                 if isinstance(arg, np.ndarray):
# --> 143                     result = target_function(np.require(arg, requirements=["C_CONTIGUOUS"]), **params)
#     144                     if isinstance(result, np.ndarray):
#     145                         res[key] = np.require(result, requirements=["C_CONTIGUOUS"])
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_asarray.py in require(a, dtype, requirements, like)
#      25
#      26
# ---> 27 @set_array_function_like_doc
#      28 @set_module('numpy')
#      29 def require(a, dtype=None, requirements=None, *, like=None):
#
# KeyboardInterrupt:
